# %%
import os

os.getcwd()
# Out:
# '/content'

# %%
# %cd 'drive/MyDrive/'
# Out:
# /content/drive/MyDrive

# %%
# %cd 'Colab Notebooks/NLP/'
# Out:
# /content/drive/My Drive/Colab Notebooks/NLP

# %%
#Initialize git
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/NLP/.git/

# %%
# !git remote add origin https://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@github.com/ritzi12/SMS_Classification_Using_DistilBERT.git

# %%
# !!git remote -v
# Out:
# ['origin\thttps://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@github.com/ritzi12/SMS_Classification_Using_DistilBERT.git (fetch)',
#  'origin\thttps://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@github.com/ritzi12/SMS_Classification_Using_DistilBERT.git (push)']

# %%
# !git config --global user.email 'cuteritzi@gmail.com'
# !git config --global user.name  'ritika'

# %%
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
